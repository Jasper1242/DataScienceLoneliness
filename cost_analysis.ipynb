# %%
import pandas as pd
import sqlite3

# %%
df_2016 = pd.read_csv('pca_stp_snomed_2016.csv')
df_2017 = pd.read_csv('pca_stp_snomed_2017.csv')
df_2018 = pd.read_csv('pca_stp_snomed_2018.csv')
df_2019 = pd.read_csv('pca_stp_snomed_2019.csv')
df_2020 = pd.read_csv('pca_stp_snomed_2020.csv')
df_2021 = pd.read_csv('pca_stp_snomed_2021.csv')
# Out:
# C:\Users\BronteKellett\AppData\Local\Temp\ipykernel_22800\633827716.py:1: DtypeWarning: Columns (5,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2016 = pd.read_csv('pca_stp_snomed_2016.csv')

# %%
frames = [df_2016,df_2017,df_2018,df_2019,df_2020,df_2021]

# %%
df = pd.concat(frames)

# %%
df[['BNF_PRESENTATION_CODE', 'BNF_PRESENTATION_NAME','GENERIC_BNF_EQUIVALENT_CODE',
       'GENERIC_BNF_EQUIVALENT_NAME', 'BNF_CHEMICAL_SUBSTANCE_CODE',
       'BNF_CHEMICAL_SUBSTANCE', 'BNF_PARAGRAPH_CODE', 'BNF_PARAGRAPH','BNF_SECTION_CODE', 'BNF_SECTION', 'BNF_CHAPTER_CODE', 'BNF_CHAPTER']]
# Out:
#        BNF_PRESENTATION_CODE  \
# 0            0406000U0AAABAB
# 1            0501011J0AAABAB
# 2            0703022M0BBABAB
# 3            0703022M0BBABAB
# 4            0803042K0BBAAAA
# ...                      ...
# 752692           23960109834
# 752693           23960709603
# 752694           23961009608
# 752695           23961009683
# 752696           23963459612
#
#                                     BNF_PRESENTATION_NAME  \
# 0       Prochlorperazine 12.5mg/1ml solution for injec...
# 1                        Benzylpenicillin 600mg inj vials
# 2          Depo-Provera 150mg/1ml inj pre-filled syringes
# 3          Depo-Provera 150mg/1ml inj pre-filled syringes
# 4       Zoladex 3.6mg implant SafeSystem pre-filled sy...
# ...                                                   ...
# 752692  Moderma Flex convex urostomy bag with CeraPlus...
# 752693             Nova 1 convex urostomy bag opaque 25mm
# 752694                    Assura urostomy bag maxi opaque
# ...

# %%
drug_data = pd.read_csv('drug_list.csv')

# %%
drug_data
# Out:
#                    illness     medication
# 0               depression     fluoxetine
# 1               depression     citalopram
# 2               depression     paroxetine
# 3               depression     sertraline
# 4               depression     dapoxetine
# 5               depression   escitalopram
# 6               depression    fluvoxamine
# 7               depression     duloxetine
# 8               depression    venlafaxine
# 9               depression    mirtazapine
# 10              depression  amitriptyline
# 11              depression   clomipramine
# 12              depression     imipramine
# 13              depression    lofepramine
# 14              depression  nortriptyline
# 15              alzheimers      donepezil
# 16              alzheimers   rivastigmine
# 17              alzheimers    galantamine
# 18          blood pressure      enalapril
# 19          blood pressure     lisinopril
# 20          blood pressure    perindopril
# ...

# %%
filtered_df = pd.DataFrame()
for i in drug_data['medication']:
    index = drug_data.index[drug_data['medication'] == 'fluoxetine'].tolist()
    contain_values = df[df['BNF_PRESENTATION_NAME'].str.contains(i,case=False)]
    contain_values['illness']=drug_data['illness'][index]
    filtered_df = pd.concat((filtered_df,contain_values))
# Out:
# C:\Users\BronteKellett\AppData\Local\Temp\ipykernel_22800\215115782.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contain_values['illness']=drug_data['illness'][index]
# C:\Users\BronteKellett\AppData\Local\Temp\ipykernel_22800\215115782.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contain_values['illness']=drug_data['illness'][index]
# C:\Users\BronteKellett\AppData\Local\Temp\ipykernel_22800\215115782.py:5: SettingWithCopyWarning:
# ...

# %%
filtered_df
# Out:
#         YEAR_DESC                                 REGION_NAME REGION_CODE  \
# 646          2016  MIDLANDS AND EAST OF ENGLAND (C 01-Apr-20)         Y55
# 647          2016  MIDLANDS AND EAST OF ENGLAND (C 01-Apr-20)         Y55
# 2163         2016  MIDLANDS AND EAST OF ENGLAND (C 01-Apr-20)         Y55
# 2164         2016  MIDLANDS AND EAST OF ENGLAND (C 01-Apr-20)         Y55
# 2165         2016  MIDLANDS AND EAST OF ENGLAND (C 01-Apr-20)         Y55
# ...           ...                                         ...         ...
# 732758       2021                    NORTH EAST AND YORKSHIRE         Y63
# 736136       2021                    NORTH EAST AND YORKSHIRE         Y63
# 736137       2021                    NORTH EAST AND YORKSHIRE         Y63
# 737030       2021                    NORTH EAST AND YORKSHIRE         Y63
# 740412       2021                    NORTH EAST AND YORKSHIRE         Y63
#
#                                                  STP_NAME STP_CODE  \
# ...

# %%
df = pd.read_csv('cost_analysis.csv')

# %%
ax = sns.barplot(df['YEAR_DESC'],df['NIC'],hue=df['illness'])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
